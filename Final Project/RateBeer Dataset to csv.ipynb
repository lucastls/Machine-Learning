# %%
import pandas as pd

# %%
import chardet    
rawdata = open('xaa', 'rb').read()
result = chardet.detect(rawdata)
charenc = result['encoding']
charenc
# Out:
# 'Windows-1252'

# %%
import re

Lista_instancias=[]

#with open("ratebeer.txt",encoding = "ISO-8859-15") as file:
with open("xaa",encoding = "ISO-8859-1") as file:
    content = file.read().split('\n\n')
    for i in range(len(content)-1):
        Dados = re.split('[a-z]*\/.*:', content[i])
        del Dados[0]
        instancia = {'Beer_Name':Dados[0].strip(),'Beer_ID':Dados[1].strip(),'Brewer_ID':Dados[2].strip(),'ABV':Dados[3].strip(),'Beer_Style':Dados[4].strip(),'Review_Appearance':Dados[5].strip(),'Review_Aroma':Dados[6].strip(),'Review_Palate':Dados[7].strip(),'Review_Taste':Dados[8].strip(), 'Review_Overall':Dados[9].strip(),'Review_Time':Dados[10].strip(),'Review_ProfileName':Dados[11].strip(),'Review_Text':Dados[12].strip()}
        Lista_instancias.append(instancia)
        
DF_teste_teste = pd.DataFrame(columns = ('Beer_Name','Beer_ID','Brewer_ID','ABV','Beer_Style','Review_Appearance','Review_Aroma','Review_Palate','Review_Taste','Review_Overall','Review_Time','Review_ProfileName','Review_Text'))        
DF_teste = pd.DataFrame(Lista_instancias)
DF_teste.head()
# Out:
#    ABV Beer_ID                           Beer_Name  \
# 0  5.4   63836            John Harvards Simcoe IPA
# 1  5.4   63836            John Harvards Simcoe IPA
# 2    5   71716       John Harvards Cristal Pilsner
# 3  5.4   64125  John Harvards Fancy Lawnmower Beer
# 4  5.4   64125  John Harvards Fancy Lawnmower Beer
#
#                      Beer_Style Brewer_ID Review_Appearance Review_Aroma  \
# 0  India Pale Ale &#40;IPA&#41;      8481               4/5         6/10
# 1  India Pale Ale &#40;IPA&#41;      8481               4/5         6/10
# 2             Bohemian Pilsener      8481               4/5         5/10
# 3                        Kölsch      8481               2/5         4/10
# 4                        Kölsch      8481               2/5         4/10
#
#   Review_Overall Review_Palate Review_ProfileName Review_Taste  \
# 0          13/20           3/5             hopdog         6/10
# 1          13/20           4/5       TomDecapolis         7/10
# ...

# %%
del Lista_instancias[:]
del Dados[:]

# %%
DF.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7921f62f56f1> in <module>()
# ----> 1 DF.info()
#
# NameError: name 'DF' is not defined

# %%
DF.to_csv()

# %%
A=DF.groupby(['Review_ProfileName']).count()['ABV'].sort_values(ascending=False).to_dict()
A
# Out:
# {'natodd': 1,
#  'Mangili': 10,
#  'ogglethorp': 866,
#  'landont3': 8,
#  'coldwon99': 7,
#  'leachiman': 3,
#  'lionel09': 6,
#  'MKane': 1,
#  'DwArK': 4,
#  'C4Warhead': 2,
#  'CptGreencoat': 92,
#  'Pedro_Tallieu': 25,
#  'sbruno': 6,
#  'JimVanGumby': 12,
#  'dvdwvr70': 5,
#  'Rendog499': 1,
#  'B3lisario': 2,
#  'thebarnesbomb': 19,
#  'elmatadora': 7,
#  'PurplePieMan': 4,
#  'vtisza': 5,
#  'morby': 2,
#  'JamesH99': 1,
#  'beergod434': 20,
#  'Prokroustis': 149,
#  'ChristianneQ': 1,
#  'finishyourbeer': 14,
#  'panunch': 2,
#  'RobChase': 7,
#  'suspect': 1,
#  'rogueman': 17,
#  'punt111usa': 8,
#  'izzy': 12,
#  'samspade10': 3,
#  'Willdrink4beer99': 8,
#  'imdrunk': 11,
#  'Jhawk99': 1,
#  'Bartonflyer': 1,
#  'jetfande': 6,
#  'stef7321': 12,
#  'tpseabird': 29,
#  'matrixmorb': 5,
#  'Steve123': 1,
#  'RolfPalla': 1,
#  'thehinge': 252,
#  'highibus': 606,
#  'Jonesy99': 2,
#  'dhatton': 2,
#  'lynchmob33': 25,
#  'beerater': 16,
#  'willhill': 3,
# ...

# %%
#DF = DF.drop(DF[A[DF.Review_ProfileName] < 5].index)
Lista_profiles=[]
for key, value in A.items():
    if value > 5:
        Lista_profiles.append(key)
print(len(Lista_profiles))
del A
del Lista_profiles
# Out:
# 11743

# %%
DF = DF[DF['Review_ProfileName'].isin(Lista_profiles)]

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2890316 entries, 0 to 2924162
# Data columns (total 13 columns):
# ABV                   object
# Beer_ID               object
# Beer_Name             object
# Beer_Style            object
# Brewer_ID             object
# Review_Appearance     object
# Review_Aroma          object
# Review_Overall        object
# Review_Palate         object
# Review_ProfileName    object
# Review_Taste          object
# Review_Text           object
# Review_Time           object
# dtypes: object(13)
# memory usage: 308.7+ MB

# %%
DF.reset_index(inplace=True)

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2890316 entries, 0 to 2890315
# Data columns (total 14 columns):
# index                 int64
# ABV                   object
# Beer_ID               object
# Beer_Name             object
# Beer_Style            object
# Brewer_ID             object
# Review_Appearance     object
# Review_Aroma          object
# Review_Overall        object
# Review_Palate         object
# Review_ProfileName    object
# Review_Taste          object
# Review_Text           object
# Review_Time           object
# dtypes: int64(1), object(13)
# memory usage: 308.7+ MB

# %%
#DF['Review_Time'] = pd.to_datetime(DF['Review_Time'].astype(int), unit='s')

# %%
#DF[['Beer_ID', 'Brewer_ID']].apply(lambda x: x.astype('int'))

# %%
DF1=DF[0:578063]

# %%
DF1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 578063 entries, 0 to 578062
# Data columns (total 14 columns):
# index                 578063 non-null int64
# ABV                   578063 non-null object
# Beer_ID               578063 non-null object
# Beer_Name             578063 non-null object
# Beer_Style            578063 non-null object
# Brewer_ID             578063 non-null object
# Review_Appearance     578063 non-null object
# Review_Aroma          578063 non-null object
# Review_Overall        578063 non-null object
# Review_Palate         578063 non-null object
# Review_ProfileName    578063 non-null object
# Review_Taste          578063 non-null object
# Review_Text           578063 non-null object
# Review_Time           578063 non-null object
# dtypes: int64(1), object(13)
# memory usage: 61.7+ MB

# %%
DF1['Review_Time'] = pd.to_datetime(DF1['Review_Time'],unit='s')
# Out:
# /home/lucas/GitHub/Python_DS_ML/ENVIRONMENT/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
DF1.head()
# Out:
#    index  ABV Beer_ID                           Beer_Name  \
# 0      0  5.4   63836            John Harvards Simcoe IPA
# 1      1  5.4   63836            John Harvards Simcoe IPA
# 2      2    5   71716       John Harvards Cristal Pilsner
# 3      3  5.4   64125  John Harvards Fancy Lawnmower Beer
# 4      4  5.4   64125  John Harvards Fancy Lawnmower Beer
#
#                      Beer_Style Brewer_ID Review_Appearance Review_Aroma  \
# 0  India Pale Ale &#40;IPA&#41;      8481               4/5         6/10
# 1  India Pale Ale &#40;IPA&#41;      8481               4/5         6/10
# 2             Bohemian Pilsener      8481               4/5         5/10
# 3                        Kölsch      8481               2/5         4/10
# 4                        Kölsch      8481               2/5         4/10
#
#   Review_Overall Review_Palate Review_ProfileName Review_Taste  \
# 0          13/20           3/5             hopdog         6/10
# ...

# %%
DF1['Review_Month'] = DF1['Review_Time'].apply(lambda time: time.month)
DF1['Review_Year'] = DF1['Review_Time'].apply(lambda time: time.year)
# Out:
# /home/lucas/GitHub/Python_DS_ML/ENVIRONMENT/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/lucas/GitHub/Python_DS_ML/ENVIRONMENT/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
DF1.head()
# Out:
#    index  ABV Beer_ID                           Beer_Name  \
# 0      0  5.4   63836            John Harvards Simcoe IPA
# 1      1  5.4   63836            John Harvards Simcoe IPA
# 2      2    5   71716       John Harvards Cristal Pilsner
# 3      3  5.4   64125  John Harvards Fancy Lawnmower Beer
# 4      4  5.4   64125  John Harvards Fancy Lawnmower Beer
#
#                      Beer_Style Brewer_ID Review_Appearance Review_Aroma  \
# 0  India Pale Ale &#40;IPA&#41;      8481               4/5         6/10
# 1  India Pale Ale &#40;IPA&#41;      8481               4/5         6/10
# 2             Bohemian Pilsener      8481               4/5         5/10
# 3                        Kölsch      8481               2/5         4/10
# 4                        Kölsch      8481               2/5         4/10
#
#   Review_Overall Review_Palate Review_ProfileName Review_Taste  \
# 0          13/20           3/5             hopdog         6/10
# ...

# %%
DF1.drop('index',axis=1)
# Out:
#          ABV Beer_ID                                          Beer_Name  \
# 0        5.4   63836                           John Harvards Simcoe IPA
# 1        5.4   63836                           John Harvards Simcoe IPA
# 2          5   71716                      John Harvards Cristal Pilsner
# 3        5.4   64125                 John Harvards Fancy Lawnmower Beer
# 4        5.4   64125                 John Harvards Fancy Lawnmower Beer
# 5          -   31544           John Harvards Vanilla Black Velvet Stout
# 6          -   71714                   John Harvards American Brown Ale
# 7          7   71719                            John Harvards Grand Cru
# 8          7   71719                            John Harvards Grand Cru
# 9          7   71719                            John Harvards Grand Cru
# 10       8.5   71715                       John Harvards Belgian Tripel
# 11         -    1470                           John Harvards Cassis Wit
# ...

# %%
DF.to_csv('Ratebeer.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1cbb2317c370> in <module>()
# ----> 1 DF.to_csv('Ratebeer.csv')
#
# NameError: name 'DF' is not defined

# %%
file='Ratebeer.csv'

DF = pd.read_csv(file,dtype=object)

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2890316 entries, 0 to 2890315
# Data columns (total 15 columns):
# Unnamed: 0            object
# index                 object
# ABV                   object
# Beer_ID               object
# Beer_Name             object
# Beer_Style            object
# Brewer_ID             object
# Review_Appearance     object
# Review_Aroma          object
# Review_Overall        object
# Review_Palate         object
# Review_ProfileName    object
# Review_Taste          object
# Review_Text           object
# Review_Time           object
# dtypes: object(15)
# memory usage: 330.8+ MB

# %%
DF.head()
# Out:
#   Unnamed: 0 index  ABV Beer_ID                           Beer_Name  \
# 0          0     0  5.4   63836            John Harvards Simcoe IPA
# 1          1     1  5.4   63836            John Harvards Simcoe IPA
# 2          2     2    5   71716       John Harvards Cristal Pilsner
# 3          3     3  5.4   64125  John Harvards Fancy Lawnmower Beer
# 4          4     4  5.4   64125  John Harvards Fancy Lawnmower Beer
#
#                      Beer_Style Brewer_ID Review_Appearance Review_Aroma  \
# 0  India Pale Ale &#40;IPA&#41;      8481               4/5         6/10
# 1  India Pale Ale &#40;IPA&#41;      8481               4/5         6/10
# 2             Bohemian Pilsener      8481               4/5         5/10
# 3                        Kölsch      8481               2/5         4/10
# 4                        Kölsch      8481               2/5         4/10
#
#   Review_Overall Review_Palate Review_ProfileName Review_Taste  \
# ...

# %%
DF.drop(['Unnamed: 0','index'],axis=1,inplace=True)

# %%
DF.head()
# Out:
#    ABV Beer_ID                           Beer_Name  \
# 0  5.4   63836            John Harvards Simcoe IPA
# 1  5.4   63836            John Harvards Simcoe IPA
# 2    5   71716       John Harvards Cristal Pilsner
# 3  5.4   64125  John Harvards Fancy Lawnmower Beer
# 4  5.4   64125  John Harvards Fancy Lawnmower Beer
#
#                      Beer_Style Brewer_ID Review_Appearance Review_Aroma  \
# 0  India Pale Ale &#40;IPA&#41;      8481               4/5         6/10
# 1  India Pale Ale &#40;IPA&#41;      8481               4/5         6/10
# 2             Bohemian Pilsener      8481               4/5         5/10
# 3                        Kölsch      8481               2/5         4/10
# 4                        Kölsch      8481               2/5         4/10
#
#   Review_Overall Review_Palate Review_ProfileName Review_Taste  \
# 0          13/20           3/5             hopdog         6/10
# 1          13/20           4/5       TomDecapolis         7/10
# ...

# %%
DF['Review_Time'] = pd.to_datetime(DF['Review_Time'],unit='s')

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2890316 entries, 0 to 2890315
# Data columns (total 13 columns):
# ABV                   object
# Beer_ID               object
# Beer_Name             object
# Beer_Style            object
# Brewer_ID             object
# Review_Appearance     object
# Review_Aroma          object
# Review_Overall        object
# Review_Palate         object
# Review_ProfileName    object
# Review_Taste          object
# Review_Text           object
# Review_Time           datetime64[ns]
# dtypes: datetime64[ns](1), object(12)
# memory usage: 286.7+ MB

# %%
DF['ABV'] = pd.to_numeric(DF['ABV'],errors='coerce')

# %%
DF['Review_Month'] = DF['Review_Time'].apply(lambda time: time.month)
DF['Review_Year'] = DF['Review_Time'].apply(lambda time: time.year)

# %%
DF['Beer_ID'] = DF['Beer_ID'].apply(lambda b_id: str(b_id))

# %%
DF['Beer_ID'] = DF['Beer_ID'].apply(lambda b_id: b_id.split('.')[0])

# %%
DF['Beer_ID'] = DF['Beer_ID'].apply(lambda b_id: int(b_id))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-bffa413fa8d9> in <module>()
# ----> 1 DF['Beer_ID'] = DF['Beer_ID'].apply(lambda b_id: int(b_id))
#
# ~/GitHub/Amb_ML/lib/python3.5/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    2353             else:
#    2354                 values = self.asobject
# -> 2355                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2356
#    2357         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer (pandas/_libs/lib.c:66645)()
#
# <ipython-input-13-bffa413fa8d9> in <lambda>(b_id)
# ----> 1 DF['Beer_ID'] = DF['Beer_ID'].apply(lambda b_id: int(b_id))
#
# ValueError: invalid literal for int() with base 10: 'la-saint-pierre-blonde-de-l`oncle-hansi-91690'

# %%
Beers_min5=DF.groupby(['Beer_Name']).count()['Review_Aroma'].sort_values(ascending=False).to_dict()

# %%
Beers_min5
# Out:
# {'Groggs Porter': 6,
#  'Sint Servattumus Liniebier 1629 FH Bier Spelt': 5,
#  'Jaipur Scottish Ale': 2,
#  'Funfair Showmans Stout': 2,
#  'Pandúr Svetlé Vy&#269;apné 10%': 7,
#  'Moylans Pomegranate Wheat': 35,
#  'Modern Monks Forbidden Ales Oktoberfest': 1,
#  'McMenamins Saison': 1,
#  'Pointe of View Winery H2BC': 8,
#  'Straffe Bink': 12,
#  'Alcatraz The Rock Bock': 8,
#  'Rudgate Auld Saint Nic': 3,
#  'Coronado Islandweizen': 29,
#  'Phantom Canyon Dunky Cold Medina': 1,
#  'Pumphouse Blackberry Wheat': 7,
#  'Malthus Fumé Light': 2,
#  'Beach Chalet Riptide Red': 29,
#  'Gillow Mr Boy\x92s Dry Cider': 4,
#  'Jasper Murdocks Sweet Barley Scotch Ale': 3,
#  'Darguner Pilsener': 55,
#  'Roosters Brewing Indian Summer': 2,
#  'Michael Sheas Blonde Lager': 8,
#  'New Glarus Unplugged Abt': 208,
#  'Hanby Taverners Ale': 5,
#  'John Harvards The Anti-Spice': 2,
#  'Friedel Schnaid Kellerbier': 3,
#  'Calumet Oktoberfest': 41,
#  'Squatters Organic Amber Ale': 24,
# ...

# %%
Beers_list=[]
for key, value in Beers_min5.items():
    if value > 5:
        Beers_list.append(key)
print(len(Beers_list))
del Beers_min5
# Out:
# 48226

# %%
DF = DF[DF['Beer_Name'].isin(Beers_list)]

# %%
del Beers_list

# %%
DF.reset_index(inplace=True)

# %%
DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2750571 entries, 0 to 2750570
# Data columns (total 16 columns):
# index                 int64
# ABV                   float64
# Beer_ID               object
# Beer_Name             object
# Beer_Style            object
# Brewer_ID             object
# Review_Appearance     object
# Review_Aroma          object
# Review_Overall        object
# Review_Palate         object
# Review_ProfileName    object
# Review_Taste          object
# Review_Text           object
# Review_Time           datetime64[ns]
# Review_Month          int64
# Review_Year           int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(11)
# memory usage: 335.8+ MB
